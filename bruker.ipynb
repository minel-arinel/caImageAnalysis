# %%
# %load_ext autoreload
# %autoreload 2

from bruker import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-79129c57d417> in <module>
#       2 get_ipython().run_line_magic('autoreload', '2')
#       3
# ----> 4 from bruker import *
#
# ~\caImageAnalysis\gavage\bruker.py in <module>
#       8 import tifffile
#       9
# ---> 10 from fish import Fish
#      11
#      12
#
# ~\caImageAnalysis\gavage\fish.py in <module>
#       4 from datetime import datetime as dt
#       5 import numpy as np
# ----> 6 import caiman as cm
#       7 from tifffile import imread, imwrite, memmap
#       8 from scipy.ndimage import rotate
#
# ModuleNotFoundError: No module named 'caiman'

# %% [markdown]
# ### Change the exp_folder to the path of the experiment

# %%
exp_folder = r'C:\Users\minel\Documents\Bruker 2P\elavl3H2BGCaMP6s_elavl3rsChRmine_10dpf_fed_none_none_0_20230630'

# %%
fish = BrukerFish(exp_folder)
fish.data_paths
# Out:
# C:\Users\minel\caImageAnalysis\gavage\bruker.py:56: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 56 of the file C:\Users\minel\caImageAnalysis\gavage\bruker.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   Bs_data = BeautifulSoup(log)
# {'bruker': {'raw_image': {'ch1': [WindowsPath('C:/Users/minel/Documents/Bruker 2P/elavl3H2BGCaMP6s_elavl3rsChRmine_10dpf_fed_none_none_0_20230630/TSeries-06302023-1145-030/TSeries-06302023-1145-030_Cycle00001_Ch1_000001.ome.tif'),
# ...
